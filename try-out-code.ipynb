# %%
import pandas as pd
import sqlite3

from dynamics.dynamics_params_test import DB_PATH

# %%
#DB_PATH = "data/crypto.sqlite"

# %%
def load_candles():
    conn = sqlite3.connect(DB_PATH)
    df = pd.read_sql_query("SELECT * FROM candles ORDER BY timestamp ASC", conn)
    conn.close()
    df["timestamp"] = pd.to_datetime(df["timestamp"])
    return df

# %%
sq = load_candles()

# %%
sq
# Out:
#                    timestamp      open      high       low     close  \
# 0  2025-05-21 08:20:00+00:00  106500.1  106500.1  106367.9  106400.0
# 1  2025-05-21 08:25:00+00:00  106400.0  106497.1  106400.0  106497.1
# 2  2025-05-21 08:30:00+00:00  106497.1  106534.9  106497.1  106534.9
# 3  2025-05-21 08:35:00+00:00  106534.8  106534.8  106446.0  106487.5
# 4  2025-05-21 08:40:00+00:00  106487.4  106487.5  106415.6  106435.7
# 5  2025-05-21 08:45:00+00:00  106435.7  106497.4  106409.4  106497.4
# 6  2025-05-21 08:50:00+00:00  106497.4  106497.4  106414.4  106414.5
# 7  2025-05-21 08:55:00+00:00  106414.5  106445.8  106414.4  106414.4
# 8  2025-05-21 09:00:00+00:00  106414.5  106546.6  106414.4  106531.1
# 9  2025-05-21 09:05:00+00:00  106531.2  106543.7  106338.0  106429.8
# 10 2025-05-21 09:10:00+00:00  106429.8  106452.7  106378.7  106378.8
# 11 2025-05-21 09:15:00+00:00  106378.7  106378.8  106261.5  106261.5
# 12 2025-05-21 09:20:00+00:00  106261.5  106325.3  106261.5  106325.3
# 13 2025-05-21 09:25:00+00:00  106328.3  106401.5  106328.2  106400.2
# 14 2025-05-21 09:30:00+00:00  106400.0  106400.0  106277.6  106277.7
# 15 2025-05-21 09:35:00+00:00  106277.7  106295.0  106277.6  106295.0
#
#        volume  pair interval
# 0    6.588394  None     None
# 1    2.293171  None     None
# 2    1.069771  None     None
# 3    2.870673  None     None
# 4    0.258707  None     None
# 5    0.433934  None     None
# 6    1.506778  None     None
# 7    0.558904  None     None
# 8    0.946827  None     None
# 9    1.516825  None     None
# 10   0.191019  None     None
# 11   0.601460  None     None
# 12   1.592701  None     None
# 13  12.571985  None     None
# 14   0.635510  None     None
# 15   0.190486  None     None
